# %% [markdown]
# # **Task 1:** Vehicle Rental System
#
# Design a Vehicle Rental System using OOP.
# Requirements:
# 1. Create a class Vehicle
# 2. Attributes: vehicle_id, brand, rent_per_day
# 3. Methods: display_details(), calculate_rent(days)
# 4. Create at least two vehicle objects
# 5. Calculate rent for different days

# %%
class Vehicle:
  __id=1
  def __init__(self, brand, rent):
    self.__vehicle_id=Vehicle.__id
    Vehicle.__id+=1
    self.__brand=brand
    self.__rent_per_day=rent

  def display_details(self):
    print('----------------------------')
    print('Vehicle id:', self.__vehicle_id)
    print('Brand:', self.__brand)
    print('Rent per day:', self.__rent_per_day)
    print('----------------------------')

  def calculate_rent(self, days):
    return self.__rent_per_day * days

cars = [Vehicle('Honda', 80000), Vehicle('Suzuki', 100000)]

while (1):
  print("============Menu============")
  cars[0].display_details()
  cars[1].display_details()
  choice=int(input("Enter car id (-1 to exit): "))
  if choice==-1:
    break
  elif choice==1 or choice==2:
    days=int(input("Enter number of days:"))
    print('----------------------------')
    print("Total Rent:", cars[choice-1].calculate_rent(days))
    print('----------------------------')
  else:
    print("Invalid choice")
  input("Press enter to continue")
  print('----------------------------')
# Out:
# ============Menu============
# ----------------------------
# Vehicle id: 1
# Brand: Honda
# Rent per day: 80000
# ----------------------------
# ----------------------------
# Vehicle id: 2
# Brand: Suzuki
# Rent per day: 100000
# ----------------------------
# Enter car id (-1 to exit): 1
# Enter number of days:3
# ----------------------------
# Total Rent: 240000
# ----------------------------
# Press enter to continue
# ----------------------------
# ============Menu============
# ----------------------------
# Vehicle id: 1
# Brand: Honda
# Rent per day: 80000
# ----------------------------
# ----------------------------
# Vehicle id: 2
# Brand: Suzuki
# Rent per day: 100000
# ----------------------------
# Enter car id (-1 to exit): 2
# Enter number of days:5
# ----------------------------
# Total Rent: 500000
# ----------------------------
# Press enter to continue
# ----------------------------
# ============Menu============
# ----------------------------
# Vehicle id: 1
# ...

# %% [markdown]
# # **Task 2:** Employee Payroll System
#
# Design an Employee Payroll System using inheritance.
# Requirements:
# 1. Base class Employee (name, emp_id)
# 2. Child classes:
# - FullTimeEmployee (monthly_salary)
# - PartTimeEmployee (hours_worked, hourly_rate)
# 3. Override calculate_salary() method
# 4. Create objects and display salary

# %%
class Employee:
  def __init__(self, name, emp_id):
    self._name=name
    self._emp_id=emp_id

  def calculate_salary(self):
    return 0

  def display(self):
    print('Name:', self._name)
    print('Employee id:', self._emp_id)

class FullTimeEmployee(Employee):
  def __init__(self, name, emp_id, monthly_salary):
    super().__init__(name, emp_id)
    self._monthly_salary=monthly_salary

  def calculate_salary(self):
    return self._monthly_salary

  def display(self):
    super().display()
    print('Monthly salary:', self._monthly_salary)

class PartTimeEmployee(Employee):
  def __init__(self, name, emp_id, hours_worked, hourly_rate):
    super().__init__(name, emp_id)
    self._hours_worked=hours_worked
    self._hourly_rate=hourly_rate

  def calculate_salary(self):
    return self._hours_worked * self._hourly_rate

  def display(self):
    super().display()
    print('Hours worked:', self._hours_worked)
    print('Hourly rate:', self._hourly_rate)
    print('Salary:', self.calculate_salary())


Employee1=FullTimeEmployee('Ali', 1, 100000)
Employee2=PartTimeEmployee('Ahmed', 2, 10, 2000)

Employee1.display()
print()
Employee2.display()
# Out:
# Name: Ali
# Employee id: 1
# Monthly salary: 100000
#
# Name: Ahmed
# Employee id: 2
# Hours worked: 10
# Hourly rate: 2000
# Salary: 20000

# %% [markdown]
# # **Task 3:** Student Result System
#
# Design a Student Result System using encapsulation.
# Requirements:
# 1. Private attribute __marks
# 2. Methods: set_marks(), get_marks(), calculate_grade()
# 3. Create at least two student objects

# %%
class Student:
  def __init__(self, id, marks=0):
    self.__id=id
    self.__marks=marks

  def set_marks(self, marks):
    if (marks>=0 and marks<=100):
      self.__marks=marks
    else:
      print("Invalid marks")

  def get_marks(self):
    return self.__marks

  def calculate_grade(self):
    if self.__marks<60:
      return "fail"
    elif self.__marks<70:
      return 'D'
    elif self.__marks<80:
      return 'C'
    elif self.__marks<90:
      return 'B'
    else:
      return 'A'

  def display(self):
    print("Roll No:", self.__id)
    print("Marks:", self.__marks)
    print("Grade:", self.calculate_grade())

student1=Student(1, 50)
student2=Student(2, 60)
student3=Student(3, 70)
student4=Student(4, 80)
student5=Student(5, 90)

student1.display()
print()
student2.display()
print()
student3.display()
print()
student4.display()
print()
student5.display()
# Out:
# Roll No: 1
# Marks: 50
# Grade: fail
#
# Roll No: 2
# Marks: 60
# Grade: D
#
# Roll No: 3
# Marks: 70
# Grade: C
#
# Roll No: 4
# Marks: 80
# Grade: B
#
# Roll No: 5
# Marks: 90
# Grade: A
